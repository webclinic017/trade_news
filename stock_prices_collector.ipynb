# %% [markdown]
# # Stock price collector

# %% [markdown]
# ## Ordinary imports

# %%
from pandas_datareader import data
from pandas_datareader._utils import RemoteDataError
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
import csv
import re
from datetime import datetime

import os.path
from os import path
import time

# import sklearn
# import scipy

# from sklearn.naive_bayes import GaussianNB
# import lightgbm as lightgbm
# from xgboost import XGBClassifier
# import keras

# Get Started
# https://github.com/Refinitiv-API-Samples/Article.EikonDataAPI.DotNet.Library
# https://developers.refinitiv.com/en/api-catalog/eikon/eikon-data-api/quick-start
# API limits
# https://developers.refinitiv.com/en/api-catalog/eikon/eikon-data-api/documentation?content=49692&type=documentation_item
import eikon as ek 

from pylab import rcParams
plt.rcParams['figure.figsize'] = 16, 8

# %%
fontsize_reg = 12
fontsize_title = 16
from pylab import rcParams
rcParams['figure.facecolor'] = '1'
rcParams['figure.figsize'] = [8.0, 3.5]
rcParams['figure.dpi'] = 80
rcParams['savefig.dpi'] = 600

rcParams['font.size'] = 12
rcParams['legend.fontsize'] = 'large'
rcParams['figure.titlesize'] = 'large'

# %% [markdown]
# ## Import custom function to collect news and prices, work with file system and modelling

# %%
import trade_news_predict_prices

# %% [markdown]
# # Some constants (path, random seeed, api key)

# %%
general_constants = pd.read_csv('general_constants.txt', sep=',', delimiter = ",", header='infer', index_col='variable_name')
general_constants
# Out:
#                                                                        value
# variable_name
# random_seed                                                              420
# directory_path                                   C:/DAN/t_systems/trade_news
# folder_name_headlines                                 data/backup_headlines/
# folder_name_logger                                              data/logger/
# folder_name_merged_news_and_prices              data/merged_news_and_prices/
# folder_name_for_labelling                                data/for_labelling/
# folder_name_for_labeled_news_iter1                  data/labeled_news_iter1/
# set_app_key1                        ccebd1ff788d4574818be93e35c4741925ac214e
# set_app_key2                        a8be043d709946238759b0c5cb34c8f90d4e6f2c

# %%
# Path to folder with directory is a constant value that stores in .txt
# You can change them in some_constants.txt file or define them on your own.
directory_path = str(general_constants.loc['directory_path'][0])
random_seed = int(general_constants.loc['random_seed'][0])
print(random_seed)
print(directory_path)
# Out:
# 420
# C:/DAN/t_systems/trade_news

# %% [markdown]
# # Set API key

# %%
# Set API key to work with thomson reuters data
# Make sure refiniv eikon terminal is running and not disconnected
print(general_constants.loc['set_app_key1'][0])
print(general_constants.loc['set_app_key2'][0])
ek.set_app_key(general_constants.loc['set_app_key2'][0])
# Out:
# ccebd1ff788d4574818be93e35c4741925ac214e
# a8be043d709946238759b0c5cb34c8f90d4e6f2c

# %% [markdown]
# # Try collect trading prices data

# %%
df = ek.get_timeseries(
    ["GOOGL.OQ"],
    interval='minute',
    start_date="2021-01-01",
    end_date="2021-01-30",
    fields=['TIMESTAMP', 'VALUE', 'VOLUME', 'HIGH', 'LOW', 'OPEN', 'CLOSE', 'COUNT'],
)

df
# Out:
# GOOGL.OQ             VALUE  VOLUME     HIGH      LOW     OPEN    CLOSE  COUNT
# Date
# 2021-01-01 00:04:00   <NA>       2  1752.60  1752.45  1752.45  1752.60      2
# 2021-01-01 00:07:00   <NA>      50  1753.15  1753.08  1753.08  1753.15      2
# 2021-01-01 00:21:00   <NA>       1  1752.82  1752.82  1752.82  1752.82      1
# 2021-01-01 00:39:00   <NA>      15  1753.96  1753.96  1753.96  1753.96      1
# 2021-01-01 00:56:00   <NA>      27  1754.08  1754.00  1754.00  1754.08      2
# ...                    ...     ...      ...      ...      ...      ...    ...
# 2021-01-29 23:41:00   <NA>       2  1827.56  1824.19  1824.19  1827.56      2
# 2021-01-29 23:46:00   <NA>       1  1823.00  1823.00  1823.00  1823.00      1
# 2021-01-29 23:47:00   <NA>      20  1824.49  1823.96  1824.49  1823.96     12
# 2021-01-29 23:55:00   <NA>      10  1822.61  1822.61  1822.61  1822.61      1
# 2021-01-30 00:00:00   <NA>       1  1822.75  1822.75  1822.75  1822.75      1
#
# [10215 rows x 7 columns]

# %%
# Read the file with all news texts to create a list with rics in it
from trade_news_predict_prices import get_name_of_latest_file_in_folder
latest_file = get_name_of_latest_file_in_folder(general_constants.loc['folder_name_headlines'][0])
all_headlines_df = pd.read_csv(latest_file, sep=';')
all_headlines_df['versionCreated'] = pd.to_datetime(all_headlines_df['versionCreated'])
print(all_headlines_df.shape, latest_file)
# Out:
# (399141, 6) data/backup_headlines/all_headlines_df_2021-03-13_v3.csv

# %%
# Create the file with rics from all news texts dataset
# (prices for companies with already collected news)
rics_list = list(all_headlines_df['ric'].value_counts().index)
print(len(rics_list), rics_list)

# rics_list = ['JPM.N', 'AMZN.OQ', 'FB.OQ', 'AAPL.OQ', 'MSFT.OQ', 'GOOGL.OQ', 'TSLA.OQ', 'BABA.N', 'PFE.N', 'RWEG.DE', 'VOWG_p.DE', 'BAC.N', 'NFLX.OQ', 'WMT.N', 'SIEGn.DE', 'LHAG.DE', 'DBKGn.DE', 'DIS.N', 'JNJ.N', 'INTC.OQ', 'DAIGn.DE', 'T.N', 'BMWG.DE', 'MRK.N', 'BAYGn.DE', 'VZ.N', 'SAPG.DE', 'EONGn.DE', 'KO.N', 'CBKG.DE', 'MA.N', 'ALVG.DE', 'NKE.N', 'TKAG.DE', 'DTEGn.DE', 'NVDA.OQ', 'V.N', 'CMCSA.OQ', 'BRKa.N', 'UNH.N', 'BASFn.DE', 'PG.N', 'HD.N', 'TMUS.OQ', 'PYPL.OQ', 'ADSGn.DE', 'DPWGn.DE', 'CONG.DE', 'LUMN.N', 'PSMGn.DE', 'MRCG.DE', 'IFXGn.DE', 'FREG.DE', 'HNKG_p.DE', 'FMEG.DE', 'ATUS.N', 'ADBE.OQ', 'CHTR.OQ', 'VNAn.DE', 'JCOM.OQ', 'HEIG.DE', 'O2Dn.DE', 'PDD.OQ', 'UTDI.DE', 'VG.OQ', 'FNTGn.DE', 'BEIG.DE', 'DRIG.DE', 'TIGO.OQ', 'BAND.OQ', 'TC1n.DE', 'IRDM.OQ', 'CABO.N', 'CCOI.OQ', 'USM.N', 'NFN.DE', 'E4CG.DE', 'PH6.F', 'IVV.P', 'VTI.P']
# Out:
# 87 ['JPM.N', 'AMZN.OQ', 'FB.OQ', 'AAPL.OQ', 'MSFT.OQ', 'GOOGL.OQ', 'TSLA.OQ', 'BABA.N', 'PFE.N', 'RWEG.DE', 'VOWG_p.DE', 'BAC.N', 'NFLX.OQ', 'WMT.N', 'SIEGn.DE', 'LHAG.DE', 'DBKGn.DE', 'DIS.N', 'JNJ.N', 'XOM.N', 'INTC.OQ', 'DAIGn.DE', 'T.N', 'BMWG.DE', 'MRK.N', 'BAYGn.DE', 'CSCO.OQ', 'VZ.N', 'SAPG.DE', 'EONGn.DE', 'CRM.N', 'KO.N', 'CBKG.DE', 'MA.N', 'ALVG.DE', 'NKE.N', 'TKAG.DE', 'DTEGn.DE', 'NVDA.OQ', 'V.N', 'CMCSA.OQ', 'BRKa.N', 'UNH.N', 'BASFn.DE', 'PG.N', 'HD.N', 'TMUS.OQ', 'ABT.N', 'ABBV.N', 'PYPL.OQ', 'PEP.OQ', 'TMO.N', 'ADSGn.DE', 'DPWGn.DE', 'CONG.DE', 'LUMN.N', 'PSMGn.DE', 'MRCG.DE', 'IFXGn.DE', 'FREG.DE', 'HNKG_p.DE', 'FMEG.DE', 'ATUS.N', 'ADBE.OQ', 'CHTR.OQ', 'VNAn.DE', 'JCOM.OQ', 'HEIG.DE', 'O2Dn.DE', 'PDD.OQ', 'UTDI.DE', 'VG.OQ', 'FNTGn.DE', 'BEIG.DE', 'DRIG.DE', 'TIGO.OQ', 'BAND.OQ', 'TC1n.DE', 'IRDM.OQ', 'CABO.N', 'CCOI.OQ', 'USM.N', 'NFN.DE', 'E4CG.DE', 'PH6.F', 'IVV.P', 'VTI.P']

# %%
# Or we can collect prices of all USA companies
rics_usa_excel = pd.read_excel('C:/DAN/t_systems/trade_project/rics_usa_excel.xlsx')
rics_list_usa = list(rics_usa_excel['ric'])
len(rics_list_usa)
# Out:
# 3803

# %%
# Or all foreign companies which are available to trade in SPb
rics_available_spb_excel = pd.read_excel('C:/DAN/t_systems/trade_project/ListingSecurityList.xlsx')
rics_list_available_spb = list(rics_available_spb_excel['ric'])
len(rics_list_available_spb)
# Out:
# 1556

# %%
# Collect prices
from trade_news_predict_prices import get_timeseries_of_rics_to_folder
get_timeseries_of_rics_to_folder(
    list_of_rics=rics_list,
    folder_for_timeseries_file='data/price_timeseries/',
    timeseries_interval='daily',
    timeseries_start_date="2010-01-01",
    timeseries_end_date="2021-06-01",
    timeseries_is_adjusted=True,
    sleep_between_rics=0.1)
# Out:
# 0 JPM.N, Attempt 1, NOT EMPTY,
#        , data/price_timeseries/price_timeseries_daily_adjusted_JPM.N.csv, 24/06/2021 18:21:22
# 1 AMZN.OQ, Attempt 1, NOT EMPTY,
#          , data/price_timeseries/price_timeseries_daily_adjusted_AMZN.OQ.csv, 24/06/2021 18:21:24
# 2 FB.OQ, Attempt 1, NOT EMPTY,
#        , data/price_timeseries/price_timeseries_daily_adjusted_FB.OQ.csv, 24/06/2021 18:21:25
# 3 AAPL.OQ, Attempt 1, NOT EMPTY,
#          , data/price_timeseries/price_timeseries_daily_adjusted_AAPL.OQ.csv, 24/06/2021 18:21:27
# 4 MSFT.OQ, Attempt 1, NOT EMPTY,
#          , data/price_timeseries/price_timeseries_daily_adjusted_MSFT.OQ.csv, 24/06/2021 18:21:28
# 5 GOOGL.OQ, Attempt 1, NOT EMPTY,
#           , data/price_timeseries/price_timeseries_daily_adjusted_GOOGL.OQ.csv, 24/06/2021 18:21:29
# 6 TSLA.OQ, Attempt 1, NOT EMPTY,
#          , data/price_timeseries/price_timeseries_daily_adjusted_TSLA.OQ.csv, 24/06/2021 18:21:30
# 7 BABA.N, Attempt 1, NOT EMPTY,
#         , data/price_timeseries/price_timeseries_daily_adjusted_BABA.N.csv, 24/06/2021 18:21:31
# 8 PFE.N, Attempt 1, NOT EMPTY,
#        , data/price_timeseries/price_timeseries_daily_adjusted_PFE.N.csv, 24/06/2021 18:21:33
# 9 RWEG.DE, Attempt 1, NOT EMPTY,
#          , data/price_timeseries/price_timeseries_daily_adjusted_RWEG.DE.csv, 24/06/2021 18:21:34
# 10 VOWG_p.DE, Attempt 1, NOT EMPTY,
#             , data/price_timeseries/price_timeseries_daily_adjusted_VOWG_p.DE.csv, 24/06/2021 18:21:37
# 11 BAC.N, Attempt 1, NOT EMPTY,
#         , data/price_timeseries/price_timeseries_daily_adjusted_BAC.N.csv, 24/06/2021 18:21:38
# 12 NFLX.OQ, Attempt 1, NOT EMPTY,
#           , data/price_timeseries/price_timeseries_daily_adjusted_NFLX.OQ.csv, 24/06/2021 18:21:39
# 13 WMT.N, Attempt 1, NOT EMPTY,
#         , data/price_timeseries/price_timeseries_daily_adjusted_WMT.N.csv, 24/06/2021 18:21:41
# 14 SIEGn.DE, Attempt 1, NOT EMPTY,
#            , data/price_timeseries/price_timeseries_daily_adjusted_SIEGn.DE.csv, 24/06/2021 18:21:42
# 15 LHAG.DE, Attempt 1, NOT EMPTY,
#           , data/price_timeseries/price_timeseries_daily_adjusted_LHAG.DE.csv, 24/06/2021 18:21:43
# 16 DBKGn.DE, Attempt 1, NOT EMPTY,
#            , data/price_timeseries/price_timeseries_daily_adjusted_DBKGn.DE.csv, 24/06/2021 18:21:45
# 17 DIS.N, Attempt 1, NOT EMPTY,
#         , data/price_timeseries/price_timeseries_daily_adjusted_DIS.N.csv, 24/06/2021 18:21:47
# 18 JNJ.N, Attempt 1, NOT EMPTY,
#         , data/price_timeseries/price_timeseries_daily_adjusted_JNJ.N.csv, 24/06/2021 18:21:48
# 19 XOM.N, Attempt 1, NOT EMPTY,
#         , data/price_timeseries/price_timeseries_daily_adjusted_XOM.N.csv, 24/06/2021 18:21:50
# 20 INTC.OQ, Attempt 1, NOT EMPTY,
#           , data/price_timeseries/price_timeseries_daily_adjusted_INTC.OQ.csv, 24/06/2021 18:21:52
# 21 DAIGn.DE, Attempt 1, NOT EMPTY,
#            , data/price_timeseries/price_timeseries_daily_adjusted_DAIGn.DE.csv, 24/06/2021 18:21:53
# 22 T.N, Attempt 1, NOT EMPTY,
#       , data/price_timeseries/price_timeseries_daily_adjusted_T.N.csv, 24/06/2021 18:21:55
# 23 BMWG.DE, Attempt 1, NOT EMPTY,
#           , data/price_timeseries/price_timeseries_daily_adjusted_BMWG.DE.csv, 24/06/2021 18:21:57
# 24 MRK.N, Attempt 1, NOT EMPTY,
#         , data/price_timeseries/price_timeseries_daily_adjusted_MRK.N.csv, 24/06/2021 18:21:59
# 25 BAYGn.DE, Attempt 1, NOT EMPTY,
#            , data/price_timeseries/price_timeseries_daily_adjusted_BAYGn.DE.csv, 24/06/2021 18:22:02
# 26 CSCO.OQ, Attempt 1, NOT EMPTY,
#           , data/price_timeseries/price_timeseries_daily_adjusted_CSCO.OQ.csv, 24/06/2021 18:22:03
# 27 VZ.N, Attempt 1, NOT EMPTY,
#        , data/price_timeseries/price_timeseries_daily_adjusted_VZ.N.csv, 24/06/2021 18:22:05
# 28 SAPG.DE, Attempt 1, NOT EMPTY,
#           , data/price_timeseries/price_timeseries_daily_adjusted_SAPG.DE.csv, 24/06/2021 18:22:06
# 29 EONGn.DE, Attempt 1, NOT EMPTY,
#            , data/price_timeseries/price_timeseries_daily_adjusted_EONGn.DE.csv, 24/06/2021 18:22:08
# 30 CRM.N, Attempt 1, NOT EMPTY,
#         , data/price_timeseries/price_timeseries_daily_adjusted_CRM.N.csv, 24/06/2021 18:22:09
# 31 KO.N, Attempt 1, NOT EMPTY,
#        , data/price_timeseries/price_timeseries_daily_adjusted_KO.N.csv, 24/06/2021 18:22:10
# 32 CBKG.DE, Attempt 1, NOT EMPTY,
#           , data/price_timeseries/price_timeseries_daily_adjusted_CBKG.DE.csv, 24/06/2021 18:22:12
# 33 MA.N, Attempt 1, NOT EMPTY,
#        , data/price_timeseries/price_timeseries_daily_adjusted_MA.N.csv, 24/06/2021 18:22:13
# 34 ALVG.DE, Attempt 1, NOT EMPTY,
#           , data/price_timeseries/price_timeseries_daily_adjusted_ALVG.DE.csv, 24/06/2021 18:22:15
# 35 NKE.N, Attempt 1, NOT EMPTY,
#         , data/price_timeseries/price_timeseries_daily_adjusted_NKE.N.csv, 24/06/2021 18:22:16
# 36 TKAG.DE, Attempt 1, NOT EMPTY,
#           , data/price_timeseries/price_timeseries_daily_adjusted_TKAG.DE.csv, 24/06/2021 18:22:17
# 37 DTEGn.DE, Attempt 1, NOT EMPTY,
#            , data/price_timeseries/price_timeseries_daily_adjusted_DTEGn.DE.csv, 24/06/2021 18:22:20
# 38 NVDA.OQ, Attempt 1, NOT EMPTY,
#           , data/price_timeseries/price_timeseries_daily_adjusted_NVDA.OQ.csv, 24/06/2021 18:22:21
# 39 V.N, Attempt 1, NOT EMPTY,
#       , data/price_timeseries/price_timeseries_daily_adjusted_V.N.csv, 24/06/2021 18:22:23
# 40 CMCSA.OQ, Attempt 1, NOT EMPTY,
#            , data/price_timeseries/price_timeseries_daily_adjusted_CMCSA.OQ.csv, 24/06/2021 18:22:25
# 41 BRKa.N, Attempt 1, NOT EMPTY,
#          , data/price_timeseries/price_timeseries_daily_adjusted_BRKa.N.csv, 24/06/2021 18:22:31
# 42 UNH.N, Attempt 1, NOT EMPTY,
#         , data/price_timeseries/price_timeseries_daily_adjusted_UNH.N.csv, 24/06/2021 18:22:33
# 43 BASFn.DE, Attempt 1, NOT EMPTY,
#            , data/price_timeseries/price_timeseries_daily_adjusted_BASFn.DE.csv, 24/06/2021 18:22:34
# 44 PG.N, Attempt 1, NOT EMPTY,
#        , data/price_timeseries/price_timeseries_daily_adjusted_PG.N.csv, 24/06/2021 18:22:36
# 45 HD.N, Attempt 1, NOT EMPTY,
#        , data/price_timeseries/price_timeseries_daily_adjusted_HD.N.csv, 24/06/2021 18:22:37
# 46 TMUS.OQ, Attempt 1, NOT EMPTY,
#           , data/price_timeseries/price_timeseries_daily_adjusted_TMUS.OQ.csv, 24/06/2021 18:22:38
# 47 ABT.N, Attempt 1, NOT EMPTY,
#         , data/price_timeseries/price_timeseries_daily_adjusted_ABT.N.csv, 24/06/2021 18:22:41
# 48 ABBV.N, Attempt 1, NOT EMPTY,
#          , data/price_timeseries/price_timeseries_daily_adjusted_ABBV.N.csv, 24/06/2021 18:22:42
# 49 PYPL.OQ, Attempt 1, NOT EMPTY,
#           , data/price_timeseries/price_timeseries_daily_adjusted_PYPL.OQ.csv, 24/06/2021 18:22:43
# 50 PEP.OQ, Attempt 1, NOT EMPTY,
#          , data/price_timeseries/price_timeseries_daily_adjusted_PEP.OQ.csv, 24/06/2021 18:22:44
# 51 TMO.N, Attempt 1, NOT EMPTY,
#         , data/price_timeseries/price_timeseries_daily_adjusted_TMO.N.csv, 24/06/2021 18:22:45
# 52 ADSGn.DE, Attempt 1, NOT EMPTY,
#            , data/price_timeseries/price_timeseries_daily_adjusted_ADSGn.DE.csv, 24/06/2021 18:22:47
# 53 DPWGn.DE, Attempt 1, NOT EMPTY,
#            , data/price_timeseries/price_timeseries_daily_adjusted_DPWGn.DE.csv, 24/06/2021 18:22:49
# 54 CONG.DE, Attempt 1, NOT EMPTY,
#           , data/price_timeseries/price_timeseries_daily_adjusted_CONG.DE.csv, 24/06/2021 18:22:50
# 55 LUMN.N, Attempt 1, NOT EMPTY,
#          , data/price_timeseries/price_timeseries_daily_adjusted_LUMN.N.csv, 24/06/2021 18:22:51
# 56 PSMGn.DE, Attempt 1, NOT EMPTY,
#            , data/price_timeseries/price_timeseries_daily_adjusted_PSMGn.DE.csv, 24/06/2021 18:22:53
# 57 MRCG.DE, Attempt 1, NOT EMPTY,
#           , data/price_timeseries/price_timeseries_daily_adjusted_MRCG.DE.csv, 24/06/2021 18:22:54
# 58 IFXGn.DE, Attempt 1, NOT EMPTY,
#            , data/price_timeseries/price_timeseries_daily_adjusted_IFXGn.DE.csv, 24/06/2021 18:22:56
# 59 FREG.DE, Attempt 1, NOT EMPTY,
#           , data/price_timeseries/price_timeseries_daily_adjusted_FREG.DE.csv, 24/06/2021 18:22:58
# 60 HNKG_p.DE, Attempt 1, NOT EMPTY,
#             , data/price_timeseries/price_timeseries_daily_adjusted_HNKG_p.DE.csv, 24/06/2021 18:22:59
# 61 FMEG.DE, Attempt 1, NOT EMPTY,
#           , data/price_timeseries/price_timeseries_daily_adjusted_FMEG.DE.csv, 24/06/2021 18:23:01
# 62 ATUS.N, Attempt 1, NOT EMPTY,
#          , data/price_timeseries/price_timeseries_daily_adjusted_ATUS.N.csv, 24/06/2021 18:23:07
# 63 ADBE.OQ, Attempt 1, NOT EMPTY,
#           , data/price_timeseries/price_timeseries_daily_adjusted_ADBE.OQ.csv, 24/06/2021 18:23:09
# 64 CHTR.OQ, Attempt 1, NOT EMPTY,
#           , data/price_timeseries/price_timeseries_daily_adjusted_CHTR.OQ.csv, 24/06/2021 18:23:10
# 65 VNAn.DE, Attempt 1, NOT EMPTY,
#           , data/price_timeseries/price_timeseries_daily_adjusted_VNAn.DE.csv, 24/06/2021 18:23:12
# 66 JCOM.OQ, Attempt 1, NOT EMPTY,
#           , data/price_timeseries/price_timeseries_daily_adjusted_JCOM.OQ.csv, 24/06/2021 18:23:14
# 67 HEIG.DE, Attempt 1, NOT EMPTY,
#           , data/price_timeseries/price_timeseries_daily_adjusted_HEIG.DE.csv, 24/06/2021 18:23:15
# 68 O2Dn.DE, Attempt 1, NOT EMPTY,
#           , data/price_timeseries/price_timeseries_daily_adjusted_O2Dn.DE.csv, 24/06/2021 18:23:16
# 69 PDD.OQ, Attempt 1, NOT EMPTY,
#          , data/price_timeseries/price_timeseries_daily_adjusted_PDD.OQ.csv, 24/06/2021 18:23:17
# 70 UTDI.DE, Attempt 1, NOT EMPTY,
#           , data/price_timeseries/price_timeseries_daily_adjusted_UTDI.DE.csv, 24/06/2021 18:23:19
# 71 VG.OQ, Attempt 1, NOT EMPTY,
#         , data/price_timeseries/price_timeseries_daily_adjusted_VG.OQ.csv, 24/06/2021 18:23:21
# 72 FNTGn.DE, Attempt 1, NOT EMPTY,
#            , data/price_timeseries/price_timeseries_daily_adjusted_FNTGn.DE.csv, 24/06/2021 18:23:22
# 73 BEIG.DE, Attempt 1, NOT EMPTY,
#           , data/price_timeseries/price_timeseries_daily_adjusted_BEIG.DE.csv, 24/06/2021 18:23:23
# 74 DRIG.DE,
# 2021-06-24 18:23:24,757 P[10784] [MainThread 18996] Error with DRIG.DE: The user does not have permission for the requested data
# 2021-06-24 18:23:24,758 P[10784] [MainThread 18996] DRIG.DE: The user does not have permission for the requested data |
# ERROR, Exception. Request fails or if server returns an error.
# Attempt 1, error with that attempt,
# 2021-06-24 18:23:35,564 P[10784] [MainThread 18996] Error with DRIG.DE: The user does not have permission for the requested data
# 2021-06-24 18:23:35,565 P[10784] [MainThread 18996] DRIG.DE: The user does not have permission for the requested data |
# ERROR, Exception. Request fails or if server returns an error.
# Attempt 2, error with that attempt,
#
#     !!! ERROR WITH THIS RIC: DRIG.DE daily 2010-01-01 2021-06-01 adjusted
#
# 75 TIGO.OQ, Attempt 1, NOT EMPTY,
#           , data/price_timeseries/price_timeseries_daily_adjusted_TIGO.OQ.csv, 24/06/2021 18:23:46
# 76 BAND.OQ, Attempt 1, NOT EMPTY,
#           , data/price_timeseries/price_timeseries_daily_adjusted_BAND.OQ.csv, 24/06/2021 18:23:49
# 77 TC1n.DE, Attempt 1, NOT EMPTY,
#           , data/price_timeseries/price_timeseries_daily_adjusted_TC1n.DE.csv, 24/06/2021 18:23:51
# 78 IRDM.OQ, Attempt 1, NOT EMPTY,
#           , data/price_timeseries/price_timeseries_daily_adjusted_IRDM.OQ.csv, 24/06/2021 18:23:52
# 79 CABO.N, Attempt 1, NOT EMPTY,
#          , data/price_timeseries/price_timeseries_daily_adjusted_CABO.N.csv, 24/06/2021 18:23:54
# 80 CCOI.OQ, Attempt 1, NOT EMPTY,
#           , data/price_timeseries/price_timeseries_daily_adjusted_CCOI.OQ.csv, 24/06/2021 18:23:55
# 81 USM.N, Attempt 1, NOT EMPTY,
#         , data/price_timeseries/price_timeseries_daily_adjusted_USM.N.csv, 24/06/2021 18:23:57
# 82 NFN.DE, Attempt 1, NOT EMPTY,
#          , data/price_timeseries/price_timeseries_daily_adjusted_NFN.DE.csv, 24/06/2021 18:23:58
# 83 E4CG.DE, Attempt 1, NOT EMPTY,
#           , data/price_timeseries/price_timeseries_daily_adjusted_E4CG.DE.csv, 24/06/2021 18:23:59
# 84 PH6.F, Attempt 1, NOT EMPTY,
#         , data/price_timeseries/price_timeseries_daily_adjusted_PH6.F.csv, 24/06/2021 18:24:00
# 85 IVV.P, Attempt 1, NOT EMPTY,
#         , data/price_timeseries/price_timeseries_daily_adjusted_IVV.P.csv, 24/06/2021 18:24:02
# 86 VTI.P, Attempt 1, NOT EMPTY,
#         , data/price_timeseries/price_timeseries_daily_adjusted_VTI.P.csv, 24/06/2021 18:24:03

# %%
list_of_files_to_merge = os.listdir('data/price_timeseries/')
print(len(list_of_files_to_merge))
# Out:
# 86

# %%
all_stock_prices = pd.DataFrame(
    data = [], 
    columns=[])

for file_now in list_of_files_to_merge:
    file_path = 'data/price_timeseries/' + file_now
    timeseries_df = pd.read_csv(file_path, sep=';')
    print(file_path, timeseries_df.shape)
    
    all_stock_prices = pd.concat([all_stock_prices, timeseries_df], ignore_index=True)
    time.sleep(0)
# Out:
# data/price_timeseries/price_timeseries_daily_adjusted_AAPL.OQ.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_ABBV.N.csv (2133, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_ABT.N.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_ADBE.OQ.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_ADSGn.DE.csv (2892, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_ALVG.DE.csv (2892, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_AMZN.OQ.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_ATUS.N.csv (992, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_BABA.N.csv (1686, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_BAC.N.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_BAND.OQ.csv (893, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_BASFn.DE.csv (2892, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_BAYGn.DE.csv (2892, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_BEIG.DE.csv (2892, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_BMWG.DE.csv (2892, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_BRKa.N.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_CABO.N.csv (1500, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_CBKG.DE.csv (2892, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_CCOI.OQ.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_CHTR.OQ.csv (2697, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_CMCSA.OQ.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_CONG.DE.csv (2892, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_CRM.N.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_CSCO.OQ.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_DAIGn.DE.csv (2892, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_DBKGn.DE.csv (2892, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_DIS.N.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_DPWGn.DE.csv (2892, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_DTEGn.DE.csv (2892, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_E4CG.DE.csv (2611, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_EONGn.DE.csv (2892, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_FB.OQ.csv (2273, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_FMEG.DE.csv (2892, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_FNTGn.DE.csv (2892, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_FREG.DE.csv (2892, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_GOOGL.OQ.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_HD.N.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_HEIG.DE.csv (2892, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_HNKG_p.DE.csv (2892, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_IFXGn.DE.csv (2892, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_INTC.OQ.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_IRDM.OQ.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_IVV.P.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_JCOM.OQ.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_JNJ.N.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_JPM.N.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_KO.N.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_LHAG.DE.csv (2892, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_LUMN.N.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_MA.N.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_MRCG.DE.csv (2892, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_MRK.N.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_MSFT.OQ.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_NFLX.OQ.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_NFN.DE.csv (770, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_NKE.N.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_NVDA.OQ.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_O2Dn.DE.csv (2166, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_PDD.OQ.csv (717, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_PEP.OQ.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_PFE.N.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_PG.N.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_PH6.F.csv (542, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_PSMGn.DE.csv (2892, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_PYPL.OQ.csv (1488, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_RWEG.DE.csv (2892, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_SAPG.DE.csv (2892, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_SIEGn.DE.csv (2892, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_T.N.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_TC1n.DE.csv (1605, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_TIGO.OQ.csv (603, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_TKAG.DE.csv (2892, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_TMO.N.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_TMUS.OQ.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_TSLA.OQ.csv (2750, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_UNH.N.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_USM.N.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_UTDI.DE.csv (2892, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_V.N.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_VG.OQ.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_VNAn.DE.csv (1992, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_VOWG_p.DE.csv (2892, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_VTI.P.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_VZ.N.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_WMT.N.csv (2872, 9)
# data/price_timeseries/price_timeseries_daily_adjusted_XOM.N.csv (2872, 9)

# %%
all_stock_prices
# Out:
#         VALUE        VOLUME       HIGH        LOW       OPEN      CLOSE  \
# 0         NaN  1.525399e+08   7.660707   7.586421   7.626778   7.649278
# 1         NaN  1.704628e+08   7.699635   7.616421   7.671064   7.656421
# 2         NaN  1.879475e+08   7.685707   7.526778   7.655707   7.534635
# 3         NaN  1.456166e+08   7.571421   7.466421   7.559992   7.520707
# 4         NaN  1.410746e+08   7.571421   7.466421   7.517492   7.570707
# ...       ...           ...        ...        ...        ...        ...
# 226141    NaN  4.471524e+06  59.500000  58.129000  59.500000  58.260000
# 226142    NaN  4.434068e+06  59.115000  57.900000  58.350000  58.940000
# 226143    NaN  1.117998e+07  59.700000  58.030000  59.240000  58.560000
# 226144    NaN  5.927672e+06  58.775000  58.115000  58.710000  58.370000
# 226145    NaN  7.004500e+06  60.690000  59.660000  59.660000  60.460000
#
#           COUNT      ric        Date
# 0           NaN  AAPL.OQ  2010-01-04
# 1           NaN  AAPL.OQ  2010-01-05
# 2           NaN  AAPL.OQ  2010-01-06
# 3           NaN  AAPL.OQ  2010-01-07
# 4           NaN  AAPL.OQ  2010-01-08
# ...         ...      ...         ...
# 226141  11367.0    XOM.N  2021-05-25
# 226142  11470.0    XOM.N  2021-05-26
# 226143  11667.0    XOM.N  2021-05-27
# 226144  10677.0    XOM.N  2021-05-28
# 226145  16558.0    XOM.N  2021-06-01
#
# [226146 rows x 9 columns]
